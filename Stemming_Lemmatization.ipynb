# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in ./miniforge3/lib/python3.12/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./miniforge3/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./miniforge3/lib/python3.12/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./miniforge3/lib/python3.12/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in ./miniforge3/lib/python3.12/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./miniforge3/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in ./miniforge3/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./miniforge3/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in ./miniforge3/lib/python3.12/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (2.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (2.13.3)
# Requirement already satisfied: jinja2 in ./miniforge3/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in ./miniforge3/lib/python3.12/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in ./miniforge3/lib/python3.12/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./miniforge3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in ./miniforge3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./miniforge3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./miniforge3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in ./miniforge3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in ./miniforge3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in ./miniforge3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in ./miniforge3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./miniforge3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in ./miniforge3/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in ./miniforge3/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in ./miniforge3/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in ./miniforge3/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.10.0)
# Requirement already satisfied: httpcore==1.* in ./miniforge3/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./miniforge3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in ./miniforge3/lib/python3.12/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: sniffio>=1.1 in ./miniforge3/lib/python3.12/site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniforge3/lib/python3.12/site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 2.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import re
import nltk
from nltk.stem import PorterStemmer
import spacy

nlp = spacy.load("en_core_web_sm")
stemmer = PorterStemmer()

text = "Running runners ran easily! Visit https://example.com"

# Cleaning
text = re.sub(r"http\S+", "", text)   # remove URLs
text = re.sub(r"[^\w\s]", "", text)   # remove punctuation

words = text.split()

# Stemming
stemmed = [stemmer.stem(word) for word in words]

# Lemmatization
doc = nlp(" ".join(words))
lemmatized = [token.lemma_ for token in doc]

print("Cleaned:", words)
print("Stemmed:", stemmed)
print("Lemmatized:", lemmatized)
# Out:
# Cleaned: ['Running', 'runners', 'ran', 'easily', 'Visit']
# Stemmed: ['run', 'runner', 'ran', 'easili', 'visit']
# Lemmatized: ['run', 'runner', 'ran', 'easily', 'visit']
