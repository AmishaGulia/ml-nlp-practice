# %%
#Step 1: Install NLTK 
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in ./miniforge3/lib/python3.12/site-packages (3.9.4)
# Requirement already satisfied: click in ./miniforge3/lib/python3.12/site-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in ./miniforge3/lib/python3.12/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in ./miniforge3/lib/python3.12/site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in ./miniforge3/lib/python3.12/site-packages (from nltk) (4.67.1)

# %%
# Step 2: Import required libraries
import nltk

# Download tokenizer data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/amisha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Step 3: Input text
text = """Natural Language Processing is a fascinating field.
It helps computers understand human language. Let's learn NLP step by step!"""

# %%
# Step 4: Sentence Tokenization
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)

print("Sentences:")
for i, sentence in enumerate(sentences, 1):
    print(f"{i}. {sentence}")
# Out:
# Sentences:
# 1. Natural Language Processing is a fascinating field.
# 2. It helps computers understand human language.
# 3. Let's learn NLP step by step!

# %%
# Step 5: Word Tokenization
from nltk.tokenize import word_tokenize

words = word_tokenize(text)

print("\nWords:")
print(words)
# Out:
# Words:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'fascinating', 'field', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'Let', "'s", 'learn', 'NLP', 'step', 'by', 'step', '!']
